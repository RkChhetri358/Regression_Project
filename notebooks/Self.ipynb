# %%
import pandas as pd
import matplotlib.pyplot as plt
import joblib
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               2.0   43525
# 3               2.2   39891
# 4               2.9   56642
# 5               3.0   60150
# 6               3.2   54445
# 7               3.9   63218
# 8               4.0   55794
# 9               4.5   61111
# 10              5.1   66029
# 11              5.9   81363
# 12              6.0   93940
# 13              6.8   91738
# 14              7.1   98273
# 15              7.9  101302
# 16              8.2  113812
# 17              8.7  109431
# 18              9.0  105582
# 19              9.5  116969
# 20             10.3  122391
# 21             10.5  121872

# %%
X=df[['YearsExperience']]
Y=df[['Salary']]

# %%
model=LinearRegression()

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# array([26433.01649344])

# %%
plt.figure(figsize=(10,10))
plt.scatter(X,Y,color='Blue')
plt.plot(X,model.predict(X),color='Black')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
joblib.dump(model,'../backend/salarytrain.pkl')
# Out:
# ['../backend/salarytrain.pkl']
