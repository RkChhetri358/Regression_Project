# %% [markdown]
# Importing the header files

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import joblib
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               2.0   43525
# 3               2.2   39891
# 4               2.9   56642
# 5               3.0   60150
# 6               3.2   54445
# 7               3.9   63218
# 8               4.0   55794
# 9               4.5   61111
# 10              5.1   66029
# 11              5.9   81363
# 12              6.0   93940
# 13              6.8   91738
# 14              7.1   98273
# 15              7.9  101302
# 16              8.2  113812
# 17              8.7  109431
# 18              9.0  105582
# 19              9.5  116969
# 20             10.3  122391
# 21             10.5  121872

# %% [markdown]
# Predict Salary(y) from expericence(x)

# %%
X=df[['YearsExperience']]
Y=df[['Salary']]

# %%
X
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               2.0
# 3               2.2
# 4               2.9
# 5               3.0
# 6               3.2
# 7               3.9
# 8               4.0
# 9               4.5
# 10              5.1
# 11              5.9
# 12              6.0
# 13              6.8
# 14              7.1
# 15              7.9
# 16              8.2
# 17              8.7
# 18              9.0
# 19              9.5
# 20             10.3
# 21             10.5

# %%
model=LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
Y_pred=model.predict(X)
intercept=model.intercept_

# %%
intercept
# Out:
# <bound method RegressorMixin.score of LinearRegression()>

# %%
plt.figure(figsize=(8,6))
plt.scatter(X,Y,color='blue',label='Data Points')
plt.plot(X,Y_pred,color='red')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# Exporting the train value

# %%
joblib.dump(model,'../backend/salary_model.pkl')
print(f"Model trained! Intercept:{model.intercept_} Coefficient: {model.coef_[0]}")
# Out:
# Model trained! Intercept:[26433.01649344] Coefficient: [9435.41541141]
